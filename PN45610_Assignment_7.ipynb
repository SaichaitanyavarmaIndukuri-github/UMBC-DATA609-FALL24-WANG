# %% [markdown]
# # 10/16/2024

# %%
import pandas as pd
import plotly.express as px

import warnings
warnings.filterwarnings('ignore')

pd.set_option("display.max_rows", None)

df = pd.read_csv("https://raw.githubusercontent.com/wcj365/python-stats-dataviz/refs/heads/master/fall2024/data/World_Development_Indicators_(WDI).csv")

print(df.shape)
df.sample(3)
# Out:
# (4123, 9)
#       Year   Country  GDP per capita (current US$)  \
# 3633  2008  Tanzania                    671.244446
# 3411  2014     Spain                  29513.651180
# 2966  2006    Poland                   9035.532758
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 3633                                58.086000         42870884.0          TZA
# 3411                                83.229268         46480882.0          ESP
# 2966                                75.143902         38141267.0          POL
#
#                      Region         Income Group    Lending Type
# 3633    Sub-Saharan Africa   Lower middle income             IDA
# 3411  Europe & Central Asia          High income  Not classified
# 2966  Europe & Central Asia          High income            IBRD

# %%
column_names_dict = {
    "GDP per capita (current US$)" : "GDP per Capita",
    "Life expectancy at birth, total (years)" : "Life Expectancy",
    "Population, total" : "Population"
}

df = df.rename(columns=column_names_dict)
df.sample(3)
# Out:
#       Year    Country  GDP per Capita  Life Expectancy  Population  \
# 1426  2005  Gibraltar             NaN           81.442     29155.0
# 2276  2019     Malawi      584.362867           64.119  18867337.0
# 2291  2015   Malaysia     9699.600463           75.094  31068833.0
#
#      Country Code                 Region         Income Group    Lending Type
# 1426          GIB  Europe & Central Asia          High income  Not classified
# 2276          MWI    Sub-Saharan Africa            Low income             IDA
# 2291          MYS    East Asia & Pacific  Upper middle income            IBRD

# %%
df.sample(3).T
# Out:
#                                 2957                   2512  \
# Year                            2016                   2008
# Country                  Philippines             Montenegro
# GDP per Capita           3038.152037            7367.751909
# Life Expectancy               71.387              75.136585
# Population               104875266.0               616969.0
# Country Code                     PHL                    MNE
# Region           East Asia & Pacific  Europe & Central Asia
# Income Group     Lower middle income    Upper middle income
# Lending Type                    IBRD                   IBRD
#
#                                   3312
# Year                              2010
# Country                       Slovenia
# GDP per Capita            23532.480855
# Life Expectancy              79.421951
# Population                   2048583.0
# Country Code                       SVN
# Region           Europe & Central Asia
# Income Group               High income
# Lending Type            Not classified

# %% [markdown]
# ## Section One
#
# Summary Statistics with describe() function

# %%
df[["Population","Life Expectancy"]].describe()
# Out:
#          Population  Life Expectancy
# count  4.123000e+03      3777.000000
# mean   3.319575e+07        71.060853
# std    1.316430e+08         8.499806
# min    9.791000e+03        42.125000
# 25%    7.436200e+05        65.351000
# 50%    5.872624e+06        72.765000
# 75%    2.148494e+07        77.529000
# max    1.417173e+09        85.497561

# %%
df.describe()
# Out:
#              Year  GDP per Capita  Life Expectancy    Population
# count  4123.00000     3962.000000      3777.000000  4.123000e+03
# mean   2013.00000    17007.692848        71.060853  3.319575e+07
# std       5.47789    25733.109164         8.499806  1.316430e+08
# min    2004.00000      128.538423        42.125000  9.791000e+03
# 25%    2008.00000     1862.892400        65.351000  7.436200e+05
# 50%    2013.00000     6048.304202        72.765000  5.872624e+06
# 75%    2018.00000    22137.309568        77.529000  2.148494e+07
# max    2022.00000   240862.182448        85.497561  1.417173e+09

# %%
df.describe(include="object")
# Out:
#             Country Country Code                 Region Income Group  \
# count          4123         4123                   4123         4123
# unique          217          217                      7            5
# top     Afghanistan          AFG  Europe & Central Asia  High income
# freq             19           19                   1102         1558
#
#           Lending Type
# count             4123
# unique               4
# top     Not classified
# freq              1387

# %%
df.describe(include="object").T
# Out:
#              count unique                    top  freq
# Country       4123    217            Afghanistan    19
# Country Code  4123    217                    AFG    19
# Region        4123      7  Europe & Central Asia  1102
# Income Group  4123      5            High income  1558
# Lending Type  4123      4         Not classified  1387

# %% [markdown]
# ## Section Two
#
# Compute quartiles and transform a numerical column into a categorical column based on the quartiles.

# %%
def assign_quartile(gdp):
    if gdp <= 1862.89:
        quartile = "1st Quartile (<=25%)"
    elif gdp > 1862.89 and gdp <= 6048.30:
        quartile = "2nd Quartile (25-50%)"
    elif gdp > 6048.30 and gdp <= 22137.31:
        quartile = "3rd Quartile (50-75%)"
    else:
        quartile = "4th Quartile (>75%)"
    return quartile


hungary = assign_quartile(14294.25)
hungary
# Out:
# '3rd Quartile (50-75%)'

# %%
df_usa = df[df["Country Code"] == "USA"]
df_usa
# Out:
#       Year        Country  GDP per Capita  Life Expectancy   Population  \
# 3914  2004  United States    41724.631629        77.487805  292805298.0
# 3915  2005  United States    44123.407068        77.487805  295516599.0
# 3916  2006  United States    46302.000880        77.687805  298379912.0
# 3917  2007  United States    48050.223777        77.987805  301231207.0
# 3918  2008  United States    48570.045980        78.039024  304093966.0
# 3919  2009  United States    47194.943355        78.390244  306771529.0
# 3920  2010  United States    48650.643128        78.541463  309327143.0
# 3921  2011  United States    50065.966504        78.641463  311583481.0
# 3922  2012  United States    51784.418574        78.741463  313877662.0
# 3923  2013  United States    53291.127689        78.741463  316059947.0
# 3924  2014  United States    55123.849787        78.841463  318386329.0
# 3925  2015  United States    56762.729452        78.690244  320738994.0
# 3926  2016  United States    57866.744934        78.539024  323071755.0
# 3927  2017  United States    59907.754261        78.539024  325122128.0
# 3928  2018  United States    62823.309438        78.639024  326838199.0
# 3929  2019  United States    65120.394663        78.787805  328329953.0
# 3930  2020  United States    63528.634303        76.980488  331511512.0
# 3931  2021  United States    70219.472454        76.329268  332031554.0
# 3932  2022  United States    76329.582265              NaN  333287557.0
#
#      Country Code         Region Income Group    Lending Type
# 3914          USA  North America  High income  Not classified
# 3915          USA  North America  High income  Not classified
# 3916          USA  North America  High income  Not classified
# 3917          USA  North America  High income  Not classified
# 3918          USA  North America  High income  Not classified
# 3919          USA  North America  High income  Not classified
# 3920          USA  North America  High income  Not classified
# 3921          USA  North America  High income  Not classified
# 3922          USA  North America  High income  Not classified
# 3923          USA  North America  High income  Not classified
# 3924          USA  North America  High income  Not classified
# 3925          USA  North America  High income  Not classified
# 3926          USA  North America  High income  Not classified
# 3927          USA  North America  High income  Not classified
# 3928          USA  North America  High income  Not classified
# 3929          USA  North America  High income  Not classified
# 3930          USA  North America  High income  Not classified
# 3931          USA  North America  High income  Not classified
# 3932          USA  North America  High income  Not classified

# %%
assign_quartile(76329.58)
# Out:
# '4th Quartile (>75%)'

# %%
df_2020 = df[df["Year"] == 2020]
print(df_2020.shape[0])
print(f"There are {df_2020.shape[0]} countries in the 2020 dataset")
df_2020.sample(3)
# Out:
# 217
# There are 217 countries in the 2020 dataset
#       Year   Country  GDP per Capita  Life Expectancy   Population  \
# 2847  2020  Pakistan     1322.314785           66.269  227196741.0
# 2144  2020   Liberia      597.529692           60.948    5087584.0
# 1612  2020     Haiti     1283.141228           64.052   11306801.0
#
#      Country Code                      Region         Income Group  \
# 2847          PAK                  South Asia  Lower middle income
# 2144          LBR         Sub-Saharan Africa            Low income
# 1612          HTI  Latin America & Caribbean   Lower middle income
#
#      Lending Type
# 2847        Blend
# 2144          IDA
# 1612          IDA

# %%
# Tuple
df_2020.shape
# Out:
# (217, 9)

# %% [markdown]
# ## In-class Exercise
#
# Create a new column call "GDP Quartile" in the df_2020 dataframe and assign each country the quartile it belongs to by applying the assign_quartile() function.

# %%
df_2020["GDP Quartile"] = df_2020["GDP per Capita"].apply(assign_quartile)

print(df_2020.shape[0])
print(df_2020["GDP Quartile"].value_counts())
# Out:
# 217
# GDP Quartile
# 4th Quartile (>75%)      61
# 2nd Quartile (25-50%)    58
# 3rd Quartile (50-75%)    54
# 1st Quartile (<=25%)     44
# Name: count, dtype: int64

# %%
df_2020.sample(10)
# Out:
#       Year                   Country  GDP per Capita  Life Expectancy  \
# 3588  2020               Switzerland    85897.784334        83.000000
# 3417  2020                     Spain    26984.296277        82.331707
# 2942  2020                      Peru     6063.626923        73.665000
# 3493  2020  St. Martin (French part)             NaN        80.149000
# 2410  2020                 Mauritius     9011.042884        74.177073
# 3379  2020              South Africa     5753.066494        65.252000
# 2467  2020                   Moldova     4376.242493        70.166000
# 1251  2020             Faroe Islands    62234.968680        83.197561
# 3398  2020               South Sudan             NaN        55.480000
# 3911  2020            United Kingdom    40217.009012        80.351220
#
#       Population Country Code                      Region  \
# 3588   8638167.0          CHE       Europe & Central Asia
# 3417  47365655.0          ESP       Europe & Central Asia
# 2942  33304756.0          PER  Latin America & Caribbean
# 3493     32553.0          MAF  Latin America & Caribbean
# 2410   1266014.0          MUS         Sub-Saharan Africa
# 3379  58801927.0          ZAF         Sub-Saharan Africa
# 2467   2635130.0          MDA       Europe & Central Asia
# 1251     52415.0          FRO       Europe & Central Asia
# 3398  10606227.0          SSD         Sub-Saharan Africa
# 3911  67081234.0          GBR       Europe & Central Asia
#
#              Income Group    Lending Type           GDP Quartile
# 3588          High income  Not classified    4th Quartile (>75%)
# 3417          High income  Not classified    4th Quartile (>75%)
# 2942  Upper middle income            IBRD  3rd Quartile (50-75%)
# 3493          High income  Not classified    4th Quartile (>75%)
# 2410  Upper middle income            IBRD  3rd Quartile (50-75%)
# 3379  Upper middle income            IBRD  2nd Quartile (25-50%)
# 2467  Upper middle income            IBRD  2nd Quartile (25-50%)
# 1251          High income  Not classified    4th Quartile (>75%)
# 3398           Low income             IDA    4th Quartile (>75%)
# 3911          High income  Not classified    4th Quartile (>75%)

# %%
df_4th = df_2020[df_2020["GDP Quartile"] == "4th Quartile (>75%)"]
df_4th.shape
# Out:
# (61, 10)

# %%
", ".join(list(df_4th["Country"]))
# Out:
# "Andorra, Aruba, Australia, Austria, Bahamas, The, Bahrain, Belgium, Bermuda, British Virgin Islands, Brunei Darussalam, Canada, Cayman Islands, Channel Islands, Cyprus, Czechia, Denmark, Eritrea, Estonia, Faroe Islands, Finland, France, Germany, Gibraltar, Greenland, Guam, Hong Kong SAR, China, Iceland, Ireland, Isle of Man, Israel, Italy, Japan, Korea, Dem. People's Rep., Korea, Rep., Kuwait, Liechtenstein, Luxembourg, Macao SAR, China, Malta, Monaco, Netherlands, New Caledonia, New Zealand, Norway, Portugal, Puerto Rico, Qatar, San Marino, Singapore, Sint Maarten (Dutch part), Slovenia, South Sudan, Spain, St. Martin (French part), Sweden, Switzerland, United Arab Emirates, United Kingdom, United States, Venezuela, RB, Virgin Islands (U.S.)"

# %%
quartile_groups = df_2020.groupby("GDP Quartile")["Country"].apply(list)


for quartile, countries in quartile_groups.items():
  print(f"{quartile}:")
  for country in countries:
      print(f"  - {country}")
  print("\n")
# Out:
# 1st Quartile (<=25%):
#   - Afghanistan
#   - Angola
#   - Benin
#   - Burkina Faso
#   - Burundi
#   - Cambodia
#   - Cameroon
#   - Central African Republic
#   - Chad
#   - Comoros
#   - Congo, Dem. Rep.
#   - Ethiopia
#   - Gambia, The
#   - Guinea
#   - Guinea-Bissau
#   - Haiti
#   - Kiribati
#   - Kyrgyz Republic
#   - Lesotho
#   - Liberia
#   - Madagascar
#   - Malawi
#   - Mali
#   - Mauritania
#   - Mozambique
#   - Myanmar
#   - Nepal
#   - Niger
#   - Pakistan
#   - Rwanda
#   - Senegal
#   - Sierra Leone
#   - Somalia
#   - Sudan
#   - Syrian Arab Republic
#   - Tajikistan
#   - Tanzania
#   - Timor-Leste
#   - Togo
#   - Uganda
#   - Uzbekistan
#   - Yemen, Rep.
#   - Zambia
#   - Zimbabwe
#
#
# 2nd Quartile (25-50%):
#   - Albania
#   - Algeria
#   - Armenia
#   - Azerbaijan
#   - Bangladesh
#   - Belize
#   - Bhutan
#   - Bolivia
#   - Botswana
#   - Cabo Verde
#   - Colombia
#   - Congo, Rep.
#   - Cote d'Ivoire
#   - Djibouti
#   - Ecuador
#   - Egypt, Arab Rep.
#   - El Salvador
#   - Eswatini
#   - Fiji
#   - Georgia
#   - Ghana
#   - Guatemala
#   - Honduras
#   - India
#   - Indonesia
#   - Iran, Islamic Rep.
#   - Iraq
#   - Jamaica
#   - Jordan
#   - Kenya
#   - Kosovo
#   - Lao PDR
#   - Lebanon
#   - Marshall Islands
#   - Micronesia, Fed. Sts.
#   - Moldova
#   - Mongolia
#   - Morocco
#   - Namibia
#   - Nicaragua
#   - Nigeria
#   - North Macedonia
#   - Papua New Guinea
#   - Paraguay
#   - Philippines
#   - Samoa
#   - Sao Tome and Principe
#   - Solomon Islands
#   - South Africa
#   - Sri Lanka
#   - Suriname
#   - Tonga
#   - Tunisia
#   - Tuvalu
#   - Ukraine
#   - Vanuatu
#   - Viet Nam
#   - West Bank and Gaza
#
#
# 3rd Quartile (50-75%):
#   - American Samoa
#   - Antigua and Barbuda
#   - Argentina
#   - Barbados
#   - Belarus
#   - Bosnia and Herzegovina
#   - Brazil
#   - Bulgaria
#   - Chile
#   - China
#   - Costa Rica
#   - Croatia
#   - Cuba
#   - Curacao
#   - Dominica
#   - Dominican Republic
#   - Equatorial Guinea
#   - French Polynesia
#   - Gabon
#   - Greece
#   - Grenada
#   - Guyana
#   - Hungary
#   - Kazakhstan
#   - Latvia
#   - Libya
#   - Lithuania
#   - Malaysia
#   - Maldives
#   - Mauritius
#   - Mexico
#   - Montenegro
#   - Nauru
#   - Northern Mariana Islands
#   - Oman
#   - Palau
#   - Panama
#   - Peru
#   - Poland
#   - Romania
#   - Russian Federation
#   - Saudi Arabia
#   - Serbia
#   - Seychelles
#   - Slovak Republic
#   - St. Kitts and Nevis
#   - St. Lucia
#   - St. Vincent and the Grenadines
#   - Thailand
#   - Trinidad and Tobago
#   - Turkiye
#   - Turkmenistan
#   - Turks and Caicos Islands
#   - Uruguay
#
#
# 4th Quartile (>75%):
#   - Andorra
#   - Aruba
#   - Australia
#   - Austria
#   - Bahamas, The
#   - Bahrain
#   - Belgium
#   - Bermuda
#   - British Virgin Islands
#   - Brunei Darussalam
#   - Canada
#   - Cayman Islands
#   - Channel Islands
#   - Cyprus
#   - Czechia
#   - Denmark
#   - Eritrea
#   - Estonia
#   - Faroe Islands
#   - Finland
#   - France
#   - Germany
#   - Gibraltar
#   - Greenland
#   - Guam
#   - Hong Kong SAR, China
#   - Iceland
#   - Ireland
#   - Isle of Man
#   - Israel
#   - Italy
#   - Japan
#   - Korea, Dem. People's Rep.
#   - Korea, Rep.
#   - Kuwait
#   - Liechtenstein
#   - Luxembourg
#   - Macao SAR, China
#   - Malta
#   - Monaco
#   - Netherlands
#   - New Caledonia
#   - New Zealand
#   - Norway
#   - Portugal
#   - Puerto Rico
#   - Qatar
#   - San Marino
#   - Singapore
#   - Sint Maarten (Dutch part)
#   - Slovenia
#   - South Sudan
#   - Spain
#   - St. Martin (French part)
#   - Sweden
#   - Switzerland
#   - United Arab Emirates
#   - United Kingdom
#   - United States
#   - Venezuela, RB
#   - Virgin Islands (U.S.)

# %%
for quartile, countries in quartile_groups.items():
  print(f"{quartile}:")
  for country in countries:
      print(f"  - {country}")
  print("\n")
# Out:
# 1st Quartile (<=25%):
#   - Afghanistan
#   - Angola
#   - Benin
#   - Burkina Faso
#   - Burundi
#   - Cambodia
#   - Cameroon
#   - Central African Republic
#   - Chad
#   - Comoros
#   - Congo, Dem. Rep.
#   - Ethiopia
#   - Gambia, The
#   - Guinea
#   - Guinea-Bissau
#   - Haiti
#   - Kiribati
#   - Kyrgyz Republic
#   - Lesotho
#   - Liberia
#   - Madagascar
#   - Malawi
#   - Mali
#   - Mauritania
#   - Mozambique
#   - Myanmar
#   - Nepal
#   - Niger
#   - Pakistan
#   - Rwanda
#   - Senegal
#   - Sierra Leone
#   - Somalia
#   - Sudan
#   - Syrian Arab Republic
#   - Tajikistan
#   - Tanzania
#   - Timor-Leste
#   - Togo
#   - Uganda
#   - Uzbekistan
#   - Yemen, Rep.
#   - Zambia
#   - Zimbabwe
#
#
# 2nd Quartile (25-50%):
#   - Albania
#   - Algeria
#   - Armenia
#   - Azerbaijan
#   - Bangladesh
#   - Belize
#   - Bhutan
#   - Bolivia
#   - Botswana
#   - Cabo Verde
#   - Colombia
#   - Congo, Rep.
#   - Cote d'Ivoire
#   - Djibouti
#   - Ecuador
#   - Egypt, Arab Rep.
#   - El Salvador
#   - Eswatini
#   - Fiji
#   - Georgia
#   - Ghana
#   - Guatemala
#   - Honduras
#   - India
#   - Indonesia
#   - Iran, Islamic Rep.
#   - Iraq
#   - Jamaica
#   - Jordan
#   - Kenya
#   - Kosovo
#   - Lao PDR
#   - Lebanon
#   - Marshall Islands
#   - Micronesia, Fed. Sts.
#   - Moldova
#   - Mongolia
#   - Morocco
#   - Namibia
#   - Nicaragua
#   - Nigeria
#   - North Macedonia
#   - Papua New Guinea
#   - Paraguay
#   - Philippines
#   - Samoa
#   - Sao Tome and Principe
#   - Solomon Islands
#   - South Africa
#   - Sri Lanka
#   - Suriname
#   - Tonga
#   - Tunisia
#   - Tuvalu
#   - Ukraine
#   - Vanuatu
#   - Viet Nam
#   - West Bank and Gaza
#
#
# 3rd Quartile (50-75%):
#   - American Samoa
#   - Antigua and Barbuda
#   - Argentina
#   - Barbados
#   - Belarus
#   - Bosnia and Herzegovina
#   - Brazil
#   - Bulgaria
#   - Chile
#   - China
#   - Costa Rica
#   - Croatia
#   - Cuba
#   - Curacao
#   - Dominica
#   - Dominican Republic
#   - Equatorial Guinea
#   - French Polynesia
#   - Gabon
#   - Greece
#   - Grenada
#   - Guyana
#   - Hungary
#   - Kazakhstan
#   - Latvia
#   - Libya
#   - Lithuania
#   - Malaysia
#   - Maldives
#   - Mauritius
#   - Mexico
#   - Montenegro
#   - Nauru
#   - Northern Mariana Islands
#   - Oman
#   - Palau
#   - Panama
#   - Peru
#   - Poland
#   - Romania
#   - Russian Federation
#   - Saudi Arabia
#   - Serbia
#   - Seychelles
#   - Slovak Republic
#   - St. Kitts and Nevis
#   - St. Lucia
#   - St. Vincent and the Grenadines
#   - Thailand
#   - Trinidad and Tobago
#   - Turkiye
#   - Turkmenistan
#   - Turks and Caicos Islands
#   - Uruguay
#
#
# 4th Quartile (>75%):
#   - Andorra
#   - Aruba
#   - Australia
#   - Austria
#   - Bahamas, The
#   - Bahrain
#   - Belgium
#   - Bermuda
#   - British Virgin Islands
#   - Brunei Darussalam
#   - Canada
#   - Cayman Islands
#   - Channel Islands
#   - Cyprus
#   - Czechia
#   - Denmark
#   - Eritrea
#   - Estonia
#   - Faroe Islands
#   - Finland
#   - France
#   - Germany
#   - Gibraltar
#   - Greenland
#   - Guam
#   - Hong Kong SAR, China
#   - Iceland
#   - Ireland
#   - Isle of Man
#   - Israel
#   - Italy
#   - Japan
#   - Korea, Dem. People's Rep.
#   - Korea, Rep.
#   - Kuwait
#   - Liechtenstein
#   - Luxembourg
#   - Macao SAR, China
#   - Malta
#   - Monaco
#   - Netherlands
#   - New Caledonia
#   - New Zealand
#   - Norway
#   - Portugal
#   - Puerto Rico
#   - Qatar
#   - San Marino
#   - Singapore
#   - Sint Maarten (Dutch part)
#   - Slovenia
#   - South Sudan
#   - Spain
#   - St. Martin (French part)
#   - Sweden
#   - Switzerland
#   - United Arab Emirates
#   - United Kingdom
#   - United States
#   - Venezuela, RB
#   - Virgin Islands (U.S.)

# %%
df_2020 = df_2020.dropna()
df_2020["GDP (Rounded)"] = df_2020["GDP per Capita"].apply(round)
df_2020.sample(5)
# Out:
#       Year          Country  GDP per Capita  Life Expectancy   Population  \
# 2771  2020  North Macedonia     5965.450232        74.395122    2072531.0
# 2638  2020            Nepal     1139.189892        69.246000   29348627.0
# 1726  2020        Indonesia     3895.618152        68.808000  271857970.0
# 2182  2020    Liechtenstein   165287.186767        81.658537      38756.0
# 2258  2020       Madagascar      462.404229        65.182000   28225177.0
#
#      Country Code                 Region         Income Group    Lending Type  \
# 2771          MKD  Europe & Central Asia  Upper middle income            IBRD
# 2638          NPL             South Asia  Lower middle income             IDA
# 1726          IDN    East Asia & Pacific  Upper middle income            IBRD
# 2182          LIE  Europe & Central Asia          High income  Not classified
# 2258          MDG    Sub-Saharan Africa            Low income             IDA
#
#                GDP Quartile  GDP (Rounded)
# 2771  2nd Quartile (25-50%)           5965
# 2638   1st Quartile (<=25%)           1139
# 1726  2nd Quartile (25-50%)           3896
# 2182    4th Quartile (>75%)         165287
# 2258   1st Quartile (<=25%)            462

# %%
def pop_million(pop):
    return pop / 1000000


df_2020["Population (Million)"] = df_2020["Population"].apply(pop_million)

df_2020.sample(5)
# Out:
#       Year      Country  GDP per Capita  Life Expectancy  Population  \
# 1194  2020      Estonia    23595.243684        78.595122   1329522.0
# 2657  2020  Netherlands    52162.570115        81.358537  17441500.0
# 3094  2020       Rwanda      773.773261        66.774000  13146362.0
# 643   2020     Cambodia     1577.911740        70.416000  16396860.0
# 3778  2020      Turkiye     8638.739133        75.850000  83384680.0
#
#      Country Code                 Region         Income Group    Lending Type  \
# 1194          EST  Europe & Central Asia          High income  Not classified
# 2657          NLD  Europe & Central Asia          High income  Not classified
# 3094          RWA    Sub-Saharan Africa            Low income             IDA
# 643           KHM    East Asia & Pacific  Lower middle income             IDA
# 3778          TUR  Europe & Central Asia  Upper middle income            IBRD
#
#                GDP Quartile  GDP (Rounded)  Population (Million)
# 1194    4th Quartile (>75%)          23595              1.329522
# 2657    4th Quartile (>75%)          52163             17.441500
# 3094   1st Quartile (<=25%)            774             13.146362
# 643    1st Quartile (<=25%)           1578             16.396860
# 3778  3rd Quartile (50-75%)           8639             83.384680

# %%
df_2020["Population2 (Million)"] = df_2020["Population"].apply(lambda pop : pop / 1000000)
df_2020.sample(5)
# Out:
#       Year          Country  GDP per Capita  Life Expectancy  Population  \
# 1992  2020      Korea, Rep.    31721.298914        83.426829  51836239.0
# 4101  2020           Zambia      956.831729        62.380000  18927715.0
# 757   2020  Channel Islands    57339.526871        81.264000    171113.0
# 643   2020         Cambodia     1577.911740        70.416000  16396860.0
# 1935  2020            Kenya     1936.250755        62.675000  51985780.0
#
#      Country Code                 Region         Income Group    Lending Type  \
# 1992          KOR    East Asia & Pacific          High income  Not classified
# 4101          ZMB    Sub-Saharan Africa   Lower middle income             IDA
# 757           CHI  Europe & Central Asia          High income  Not classified
# 643           KHM    East Asia & Pacific  Lower middle income             IDA
# 1935          KEN    Sub-Saharan Africa   Lower middle income           Blend
#
#                GDP Quartile  GDP (Rounded)  Population (Million)  \
# 1992    4th Quartile (>75%)          31721             51.836239
# 4101   1st Quartile (<=25%)            957             18.927715
# 757     4th Quartile (>75%)          57340              0.171113
# 643    1st Quartile (<=25%)           1578             16.396860
# 1935  2nd Quartile (25-50%)           1936             51.985780
#
#       Population2 (Million)
# 1992              51.836239
# 4101              18.927715
# 757                0.171113
# 643               16.396860
# 1935              51.985780

# %% [markdown]
# ## Homework Question 1
#
# Save the summary statistics of all numerical columns and all categorical columns to only one Excel spreadsheet file with two worksheets, one for numerical and one for categorical columns.

# %%
import pandas as pd


df = pd.read_csv("https://raw.githubusercontent.com/wcj365/python-stats-dataviz/refs/heads/master/fall2024/data/World_Development_Indicators_(WDI).csv")  # or use another method to load data

# Separate numerical and categorical columns
numerical_cols = df.select_dtypes(include=['number']).columns
categorical_cols = df.select_dtypes(include=['object', 'category']).columns

# Summary for numerical columns
numerical_summary = df[numerical_cols].describe()
print("Numerical Summary Statistics:")
print(numerical_summary)

# Summary for categorical columns (unique counts and frequencies)
categorical_summary = df[categorical_cols].apply(lambda x: x.value_counts()).T
print("Categorical Summary Statistics:")
print(categorical_summary)

# Save to Excel file with two sheets
with pd.ExcelWriter('summary_statistics.xlsx') as writer:
    numerical_summary.to_excel(writer, sheet_name='Numerical')
    categorical_summary.to_excel(writer, sheet_name='Categorical')
# Out:
# Numerical Summary Statistics:
#              Year  GDP per capita (current US$)  \
# count  4123.00000                   3962.000000
# mean   2013.00000                  17007.692848
# std       5.47789                  25733.109164
# min    2004.00000                    128.538423
# 25%    2008.00000                   1862.892400
# 50%    2013.00000                   6048.304202
# 75%    2018.00000                  22137.309568
# max    2022.00000                 240862.182448
#
#        Life expectancy at birth, total (years)  Population, total
# count                              3777.000000       4.123000e+03
# mean                                 71.060853       3.319575e+07
# std                                   8.499806       1.316430e+08
# min                                  42.125000       9.791000e+03
# 25%                                  65.351000       7.436200e+05
# 50%                                  72.765000       5.872624e+06
# 75%                                  77.529000       2.148494e+07
# max                                  85.497561       1.417173e+09
# Categorical Summary Statistics:
#                ABW   AFG   AGO   ALB   AND   ARE   ARG   ARM   ASM   ATG  ...  \
# Country        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Country Code  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  ...
# Region         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Income Group   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Lending Type   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#                WSM  West Bank and Gaza   XKX   YEM  Yemen, Rep.   ZAF   ZMB  \
# Country        NaN                19.0   NaN   NaN         19.0   NaN   NaN
# Country Code  19.0                 NaN  19.0  19.0          NaN  19.0  19.0
# Region         NaN                 NaN   NaN   NaN          NaN   NaN   NaN
# Income Group   NaN                 NaN   NaN   NaN          NaN   NaN   NaN
# Lending Type   NaN                 NaN   NaN   NaN          NaN   NaN   NaN
#
#                ZWE  Zambia  Zimbabwe
# Country        NaN    19.0      19.0
# Country Code  19.0     NaN       NaN
# Region         NaN     NaN       NaN
# Income Group   NaN     NaN       NaN
# Lending Type   NaN     NaN       NaN
#
# [5 rows x 449 columns]

# %%
# for df_2020

numerical_summary = df_2020.describe()
print("Numerical Summary Statistics:")
print(numerical_summary)

categorical_summary = df_2020.describe(include="object").T
print("Categorical Summary Statistics:")
print(categorical_summary)


# Save to Excel file with two sheets
with pd.ExcelWriter('summary_statistics.xlsx') as writer:
    numerical_summary.to_excel(writer, sheet_name='Numerical')
    categorical_summary.to_excel(writer, sheet_name='Categorical')
# Out:
# Numerical Summary Statistics:
#          Year  GDP per Capita  Life Expectancy    Population  GDP (Rounded)  \
# count   202.0      202.000000       202.000000  2.020000e+02     202.000000
# mean   2020.0    16198.267524        72.314599  3.825505e+07   16198.277228
# std       0.0    23391.117592         7.451962  1.446623e+08   23391.118369
# min    2020.0      216.827417        52.777000  1.106900e+04     217.000000
# 25%    2020.0     2188.047693        66.779750  1.307377e+06    2188.250000
# 50%    2020.0     5920.260419        72.871500  6.916570e+06    5920.000000
# 75%    2020.0    20761.211199        77.981750  2.673161e+07   20761.000000
# max    2020.0   165287.186767        85.497561  1.411100e+09  165287.000000
#
#        Population (Million)  Population2 (Million)  GDP per Capita (Rounded)
# count            202.000000             202.000000                202.000000
# mean              38.255054              38.255054              16198.267475
# std              144.662308             144.662308              23391.117891
# min                0.011069               0.011069                216.830000
# 25%                1.307377               1.307377               2188.050000
# 50%                6.916570               6.916570               5920.260000
# 75%               26.731614              26.731614              20761.210000
# max             1411.100000            1411.100000             165287.190000
# Categorical Summary Statistics:
#              count unique                    top freq
# Country        202    202            Afghanistan    1
# Country Code   202    202                    AFG    1
# Region         202      7  Europe & Central Asia   54
# Income Group   202      4            High income   72
# Lending Type   202      4                   IBRD   67
# GDP Quartile   202      4  2nd Quartile (25-50%)   58

# %% [markdown]
# ## Homework Question 2
#
# Create a new column that is the GDP per Capita rounded to 2 decimal points by using the Python's build function "round"
# Hint: apply the round function/method and provide a parameter 2.

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/wcj365/python-stats-dataviz/refs/heads/master/fall2024/data/World_Development_Indicators_(WDI).csv")

# Apply the round function to GDP per Capita and create a new column
df['GDP per Capita (rounded)'] = df['GDP per capita (current US$)'].apply(lambda x: round(x, 2))

# Display the first few rows to verify the new column
print(df[['GDP per capita (current US$)', 'GDP per Capita (rounded)']].head())
# Out:
#    GDP per capita (current US$)  GDP per Capita (rounded)
# 0                    221.830531                    221.83
# 1                    254.115274                    254.12
# 2                    274.015394                    274.02
# 3                    376.318296                    376.32
# 4                    382.533804                    382.53

# %%
df_2020["GDP per Capita (Rounded)"] = df_2020["GDP per Capita"].apply(lambda x: round(x, 2))

df_2020.sample(5)
# Out:
#       Year   Country  GDP per Capita  Life Expectancy  Population  \
# 2315  2020  Maldives     7216.816371         79.87500    514438.0
# 4025  2020  Viet Nam     3586.347176         75.37800  96648685.0
# 928   2020   Croatia    14269.908855         77.72439   4047680.0
# 3664  2020  Thailand     7001.785460         79.27400  71475664.0
# 2125  2020   Lesotho      917.356381         54.69300   2254100.0
#
#      Country Code                 Region         Income Group Lending Type  \
# 2315          MDV             South Asia  Upper middle income          IDA
# 4025          VNM    East Asia & Pacific  Lower middle income         IBRD
# 928           HRV  Europe & Central Asia          High income         IBRD
# 3664          THA    East Asia & Pacific  Upper middle income         IBRD
# 2125          LSO    Sub-Saharan Africa   Lower middle income          IDA
#
#                GDP Quartile  GDP (Rounded)  Population (Million)  \
# 2315  3rd Quartile (50-75%)           7217              0.514438
# 4025  2nd Quartile (25-50%)           3586             96.648685
# 928   3rd Quartile (50-75%)          14270              4.047680
# 3664  3rd Quartile (50-75%)           7002             71.475664
# 2125   1st Quartile (<=25%)            917              2.254100
#
#       Population2 (Million)  GDP per Capita (Rounded)
# 2315               0.514438                   7216.82
# 4025              96.648685                   3586.35
# 928                4.047680                  14269.91
# 3664              71.475664                   7001.79
# 2125               2.254100                    917.36

# %% [markdown]
# ## Homework Question 3 (bonus, will cover next week)
#
# step 1 - create a column "Life Expectancy Quartile" similar to the GDP per Capita Quartile above.
# Step 2 - Create a column "health and wealth status" based on the following definition
# - rich and healthy (1st GDP per capita quartile and 1st life expentancy quartile)
# - poor and unhealthy ((4th GDP per capita quartile and 4th life expentancy quartile)
# - rich and unhealthy (1st GDP per capita quartile and 4th life expentancy quartile)
# - poor and healthy ((4th GDP per capita quartile and 1st life expentancy quartile)
# - Other

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("https://raw.githubusercontent.com/wcj365/python-stats-dataviz/refs/heads/master/fall2024/data/World_Development_Indicators_(WDI).csv")

# Step 1: Create the "GDP per Capita Quartile" and "Life Expectancy Quartile"

# Dropping NA values from the relevant columns for clean quartile calculation

df = df.dropna(subset=['GDP per capita (current US$)', 'Life expectancy at birth, total (years)'])

# Create GDP per Capita Quartile
df['GDP per Capita Quartile'] = pd.qcut(df['GDP per capita (current US$)'], 4, labels=[1, 2, 3, 4])

# Create Life Expectancy Quartile
df['Life Expectancy Quartile'] = pd.qcut(df['Life expectancy at birth, total (years)'], 4, labels=[1, 2, 3, 4])

# Step 2: Create the "health and wealth status" column based on the given definition
def health_wealth_status(row):
    if row['GDP per Capita Quartile'] == 1 and row['Life Expectancy Quartile'] == 1:
        return 'rich and healthy'
    elif row['GDP per Capita Quartile'] == 4 and row['Life Expectancy Quartile'] == 4:
        return 'poor and unhealthy'
    elif row['GDP per Capita Quartile'] == 1 and row['Life Expectancy Quartile'] == 4:
        return 'rich and unhealthy'
    elif row['GDP per Capita Quartile'] == 4 and row['Life Expectancy Quartile'] == 1:
        return 'poor and healthy'
    else:
        return 'Other'

# Apply the function to each row to create the new column
df['health and wealth status'] = df.apply(health_wealth_status, axis=1)

# Display the first few rows to verify the results
print(df[['GDP per capita (current US$)', 'Life expectancy at birth, total (years)',
          'GDP per Capita Quartile', 'Life Expectancy Quartile', 'health and wealth status']].head())
# Out:
#    GDP per capita (current US$)  Life expectancy at birth, total (years)  \
# 0                    221.830531                                   57.944
# 1                    254.115274                                   58.361
# 2                    274.015394                                   58.684
# 3                    376.318296                                   59.111
# 4                    382.533804                                   59.852
#
#   GDP per Capita Quartile Life Expectancy Quartile health and wealth status
# 0                       1                        1         rich and healthy
# 1                       1                        1         rich and healthy
# 2                       1                        1         rich and healthy
# 3                       1                        1         rich and healthy
# 4                       1                        1         rich and healthy

# %%
df.sample(55)
# Out:
#       Year                   Country  GDP per capita (current US$)  \
# 1376  2012                   Georgia                   4421.930712
# 765   2009                     Chile                  10204.558854
# 1507  2010                      Guam                  30011.218580
# 2645  2008               Netherlands                  57879.943755
# 1096  2017                   Ecuador                   6246.404252
# 381   2005                     Benin                    805.904685
# 434   2020                    Bhutan                   3181.339747
# 3926  2016             United States                  57866.744934
# 2328  2014                      Mali                    818.430341
# 1780  2017                   Ireland                  70150.737016
# 1668  2019                   Hungary                  16786.213640
# 1320  2013          French Polynesia                  20941.517340
# 1060  2019                  Dominica                   8561.587011
# 3194  2006                    Serbia                   4382.617279
# 2544  2021                   Morocco                   3767.524902
# 546   2018         Brunei Darussalam                  31240.501789
# 2675  2019             New Caledonia                  34934.579430
# 3681  2018               Timor-Leste                   1241.164485
# 510   2020                    Brazil                   6923.699912
# 1675  2007                   Iceland                  69495.726738
# 2995  2016                  Portugal                  19991.972488
# 2520  2016                Montenegro                   7033.439624
# 2041  2012           Kyrgyz Republic                   1177.975261
# 3033  2016                     Qatar                  58467.235571
# 1478  2019                 Greenland                  53309.203591
# 2055  2007                   Lao PDR                    699.041376
# 2379  2008                Mauritania                   1610.236979
# 3811  2015  Turks and Caicos Islands                  25783.294105
# 2428  2019                    Mexico                  10434.578365
# 2018  2008                    Kuwait                  55595.484313
# 168   2020                   Armenia                   4505.867742
# 2432  2004     Micronesia, Fed. Sts.                   2155.781690
# 1400  2017                   Germany                  44652.589172
# 2753  2021                   Nigeria                   2065.774410
# 2000  2009                    Kosovo                   2847.555339
# 2655  2018               Netherlands                  53044.532435
# 851   2019          Congo, Dem. Rep.                    575.882781
# 989   2005                   Czechia                  13430.669896
# 979   2014                    Cyprus                  27162.322266
# 2079  2012                    Latvia                  13847.337939
# 2909  2006                  Paraguay                   2426.417098
# 2901  2017          Papua New Guinea                   2495.140773
# 2996  2017                  Portugal                  21490.429863
# 657   2015                  Cameroon                   1399.675336
# 2881  2016                    Panama                  14382.232382
# 831   2018                   Comoros                   1531.337811
# 291   2010                Bangladesh                    776.859577
# 2451  2004                   Moldova                    897.178495
# 4115  2015                  Zimbabwe                   1410.329173
# 2585  2005                   Namibia                   3692.752603
# 2574  2013                   Myanmar                   1189.964765
# 1379  2015                   Georgia                   4014.111651
# 207   2021                 Australia                  60697.245436
# 2215  2015                Luxembourg                 105462.012584
# 211   2006                   Austria                  40669.326959
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 1376                                72.412000          3728874.0          GEO
# 765                                 78.741000         16833447.0          CHL
# 1507                                76.879000           164905.0          GUM
# 2645                                80.251220         16445593.0          NLD
# 1096                                76.972000         16696944.0          ECU
# 381                                 57.125000          8149419.0          BEN
# 434                                 71.609000           772506.0          BTN
# 3926                                78.539024        323071755.0          USA
# 2328                                57.900000         17551814.0          MLI
# 1780                                82.156098          4807388.0          IRL
# 1668                                76.319512          9771141.0          HUN
# 1320                                82.017000           288032.0          PYF
# 1060                                73.559000            71428.0          DMA
# 3194                                73.385366          7411569.0          SRB
# 2544                                74.042000         37076584.0          MAR
# 546                                 74.712000           434274.0          BRN
# 2675                                80.419707           271240.0          NCL
# 3681                                68.017000          1261845.0          TLS
# 510                                 74.009000        213196304.0          BRA
# 1675                                81.453659           311566.0          ISL
# 2995                                81.124390         10325452.0          PRT
# 2520                                76.441463           622303.0          MNE
# 2041                                70.002439          5607200.0          KGZ
# 3033                                80.433000          2595166.0          QAT
# 1478                                72.043659            56225.0          GRL
# 2055                                62.084000          6041348.0          LAO
# 2379                                62.399000          3233336.0          MRT
# 3811                                76.912000            36538.0          TCA
# 2428                                74.202000        125085311.0          MEX
# 2018                                77.145000          2650930.0          KWT
# 168                                 72.173000          2805608.0          ARM
# 2432                                70.838000           111438.0          FSM
# 1400                                80.992683         82657002.0          DEU
# 2753                                52.676000        213401323.0          NGA
# 2000                                77.665000          1761474.0          XKX
# 2655                                81.812195         17231624.0          NLD
# 851                                 60.276000         89906890.0          COD
# 989                                 75.924390         10211216.0          CZE
# 979                                 80.771000          1176995.0          CYP
# 2079                                73.778049          2034319.0          LVA
# 2909                                70.781000          5534675.0          PRY
# 2901                                65.103000          9114796.0          PNG
# 2996                                81.424390         10300300.0          PRT
# 657                                 59.658000         23012646.0          CMR
# 2881                                77.653000          4026336.0          PAN
# 831                                 63.912000           776313.0          COM
# 291                                 68.638000        148391139.0          BGD
# 2451                                67.861000          2896023.0          MDA
# 4115                                59.591000         14154937.0          ZWE
# 2585                                51.787000          1962865.0          NAM
# 2574                                64.815000         50648334.0          MMR
# 1379                                73.297000          3725276.0          GEO
# 207                                 83.300000         25685412.0          AUS
# 2215                                82.292683           569604.0          LUX
# 211                                 79.880488          8268641.0          AUT
#
#                           Region         Income Group    Lending Type  \
# 1376       Europe & Central Asia  Upper middle income            IBRD
# 765   Latin America & Caribbean           High income            IBRD
# 1507         East Asia & Pacific          High income  Not classified
# 2645       Europe & Central Asia          High income  Not classified
# 1096  Latin America & Caribbean   Upper middle income            IBRD
# 381          Sub-Saharan Africa   Lower middle income             IDA
# 434                   South Asia  Lower middle income             IDA
# 3926               North America          High income  Not classified
# 2328         Sub-Saharan Africa            Low income             IDA
# 1780       Europe & Central Asia          High income  Not classified
# 1668       Europe & Central Asia          High income  Not classified
# 1320         East Asia & Pacific          High income  Not classified
# 1060  Latin America & Caribbean   Upper middle income           Blend
# 3194       Europe & Central Asia  Upper middle income            IBRD
# 2544  Middle East & North Africa  Lower middle income            IBRD
# 546          East Asia & Pacific          High income  Not classified
# 2675         East Asia & Pacific          High income  Not classified
# 3681         East Asia & Pacific  Lower middle income           Blend
# 510   Latin America & Caribbean   Upper middle income            IBRD
# 1675       Europe & Central Asia          High income  Not classified
# 2995       Europe & Central Asia          High income  Not classified
# 2520       Europe & Central Asia  Upper middle income            IBRD
# 2041       Europe & Central Asia  Lower middle income             IDA
# 3033  Middle East & North Africa          High income  Not classified
# 1478       Europe & Central Asia          High income  Not classified
# 2055         East Asia & Pacific  Lower middle income             IDA
# 2379         Sub-Saharan Africa   Lower middle income             IDA
# 3811  Latin America & Caribbean           High income  Not classified
# 2428  Latin America & Caribbean   Upper middle income            IBRD
# 2018  Middle East & North Africa          High income  Not classified
# 168        Europe & Central Asia  Upper middle income            IBRD
# 2432         East Asia & Pacific  Lower middle income             IDA
# 1400       Europe & Central Asia          High income  Not classified
# 2753         Sub-Saharan Africa   Lower middle income           Blend
# 2000       Europe & Central Asia  Upper middle income             IDA
# 2655       Europe & Central Asia          High income  Not classified
# 851          Sub-Saharan Africa            Low income             IDA
# 989        Europe & Central Asia          High income  Not classified
# 979        Europe & Central Asia          High income  Not classified
# 2079       Europe & Central Asia          High income  Not classified
# 2909  Latin America & Caribbean   Upper middle income            IBRD
# 2901         East Asia & Pacific  Lower middle income           Blend
# 2996       Europe & Central Asia          High income  Not classified
# 657          Sub-Saharan Africa   Lower middle income           Blend
# 2881  Latin America & Caribbean           High income            IBRD
# 831          Sub-Saharan Africa   Lower middle income             IDA
# 291                   South Asia  Lower middle income             IDA
# 2451       Europe & Central Asia  Upper middle income            IBRD
# 4115         Sub-Saharan Africa   Lower middle income           Blend
# 2585         Sub-Saharan Africa   Upper middle income            IBRD
# 2574         East Asia & Pacific  Lower middle income             IDA
# 1379       Europe & Central Asia  Upper middle income            IBRD
# 207          East Asia & Pacific          High income  Not classified
# 2215       Europe & Central Asia          High income  Not classified
# 211        Europe & Central Asia          High income  Not classified
#
#      GDP per Capita Quartile Life Expectancy Quartile health and wealth status
# 1376                       2                        2                    Other
# 765                        3                        4                    Other
# 1507                       4                        3                    Other
# 2645                       4                        4       poor and unhealthy
# 1096                       3                        3                    Other
# 381                        1                        1         rich and healthy
# 434                        2                        2                    Other
# 3926                       4                        4       poor and unhealthy
# 2328                       1                        1         rich and healthy
# 1780                       4                        4       poor and unhealthy
# 1668                       3                        3                    Other
# 1320                       4                        4       poor and unhealthy
# 1060                       3                        3                    Other
# 3194                       2                        3                    Other
# 2544                       2                        3                    Other
# 546                        4                        3                    Other
# 2675                       4                        4       poor and unhealthy
# 3681                       1                        2                    Other
# 510                        3                        3                    Other
# 1675                       4                        4       poor and unhealthy
# 2995                       3                        4                    Other
# 2520                       3                        3                    Other
# 2041                       1                        2                    Other
# 3033                       4                        4       poor and unhealthy
# 1478                       4                        2                    Other
# 2055                       1                        1         rich and healthy
# 2379                       1                        1         rich and healthy
# 3811                       4                        3                    Other
# 2428                       3                        3                    Other
# 2018                       4                        3                    Other
# 168                        2                        2                    Other
# 2432                       2                        2                    Other
# 1400                       4                        4       poor and unhealthy
# 2753                       2                        1                    Other
# 2000                       2                        4                    Other
# 2655                       4                        4       poor and unhealthy
# 851                        1                        1         rich and healthy
# 989                        3                        3                    Other
# 979                        4                        4       poor and unhealthy
# 2079                       3                        3                    Other
# 2909                       2                        2                    Other
# 2901                       2                        1                    Other
# 2996                       4                        4       poor and unhealthy
# 657                        1                        1         rich and healthy
# 2881                       3                        4                    Other
# 831                        1                        1         rich and healthy
# 291                        1                        2                    Other
# 2451                       1                        2                    Other
# 4115                       1                        1         rich and healthy
# 2585                       2                        1                    Other
# 2574                       1                        1         rich and healthy
# 1379                       2                        3                    Other
# 207                        4                        4       poor and unhealthy
# 2215                       4                        4       poor and unhealthy
# 211                        4                        4       poor and unhealthy

# %%
df_2020.sample(5)
# Out:
#       Year      Country  GDP per Capita  Life Expectancy   Population  \
# 3854  2020       Uganda      846.881199           62.851   44404611.0
# 2885  2020       Panama    13293.333195           76.657    4294396.0
# 2429  2020       Mexico     8894.890650           70.133  125998302.0
# 871   2020  Congo, Rep.     2011.269479           63.785    5702174.0
# 1859  2020      Jamaica     4897.264750           71.869    2820436.0
#
#      Country Code                      Region         Income Group  \
# 3854          UGA         Sub-Saharan Africa            Low income
# 2885          PAN  Latin America & Caribbean           High income
# 2429          MEX  Latin America & Caribbean   Upper middle income
# 871           COG         Sub-Saharan Africa   Lower middle income
# 1859          JAM  Latin America & Caribbean   Upper middle income
#
#      Lending Type           GDP Quartile  GDP (Rounded)  Population (Million)  \
# 3854          IDA   1st Quartile (<=25%)            847             44.404611
# 2885         IBRD  3rd Quartile (50-75%)          13293              4.294396
# 2429         IBRD  3rd Quartile (50-75%)           8895            125.998302
# 871         Blend  2nd Quartile (25-50%)           2011              5.702174
# 1859         IBRD  2nd Quartile (25-50%)           4897              2.820436
#
#       Population2 (Million)  GDP per Capita (Rounded)
# 3854              44.404611                    846.88
# 2885               4.294396                  13293.33
# 2429             125.998302                   8894.89
# 871                5.702174                   2011.27
# 1859               2.820436                   4897.26
